# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
# Memuat dataset
df = pd.read_csv('heart.csv')

df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Pemisahan data menjadi fitur (X) dan target (y)
X = df.drop('target', axis=1).values
y = df['target'].values

# %%
# Normalisasi data fitur menggunakan StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Membagi data menjadi data training dan testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Mengonversi data menjadi tensor untuk digunakan dalam PyTorch
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# %%
# Membuat model Multi-Layer Perceptron (MLP)
def create_mlp(input_size, hidden_layers, hidden_neurons, activation_function):
    layers = []

    # Menambahkan lapisan input ke lapisan tersembunyi pertama
    layers.append(nn.Linear(input_size, hidden_neurons))

    # Menambahkan lapisan tersembunyi tambahan
    for _ in range(hidden_layers - 1):
        layers.append(nn.Linear(hidden_neurons, hidden_neurons))

    # Memilih fungsi aktivasi berdasarkan parameter
    if activation_function == 'linear':
        activation = nn.Identity()
    elif activation_function == 'Sigmoid':
        activation = nn.Sigmoid()
    elif activation_function == 'ReLU':
        activation = nn.ReLU()
    elif activation_function == 'Softmax':
        activation = nn.Softmax(dim=1)
    elif activation_function == 'Tanh':
        activation = nn.Tanh()

    # Menambahkan fungsi aktivasi setelah setiap lapisan tersembunyi
    for i in range(1, len(layers)):
        layers.insert(i, activation)
        i += 1

    # Menambahkan lapisan output untuk klasifikasi 2 kelas (0 atau 1)
    layers.append(nn.Linear(hidden_neurons, 2))

    # Menggabungkan semua lapisan menjadi satu model
    model = nn.Sequential(*layers)
    return model

# %%
# Fungsi untuk melatih dan mengevaluasi model
def train_and_evaluate(model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate):
    # Membuat DataLoader untuk pembagian data pelatihan dalam batch
    train_data = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

    # Menginisialisasi optimizer (Adam) dan fungsi loss (CrossEntropyLoss untuk klasifikasi)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    # Proses pelatihan model
    model.train()  # Mengatur model ke mode pelatihan
    for epoch in range(epochs):
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()  # Mengatur ulang gradien
            output = model(X_batch)  # Melakukan prediksi dengan model
            loss = criterion(output, y_batch)  # Menghitung nilai loss
            loss.backward()  # Melakukan backpropagation
            optimizer.step()  # Memperbarui parameter model

    # Proses evaluasi model setelah pelatihan selesai
    model.eval()  # Mengatur model ke mode evaluasi (tanpa pembaruan gradien)
    with torch.no_grad():  # Menonaktifkan perhitungan gradien untuk efisiensi
        # Evaluasi pada data pelatihan
        train_output = model(X_train_tensor)
        train_pred = torch.argmax(train_output, dim=1)  # Prediksi kelas dengan argmax
        train_accuracy = accuracy_score(y_train_tensor.numpy(), train_pred.numpy())  # Menghitung akurasi data pelatihan
        train_loss = criterion(train_output, y_train_tensor).item()  # Menghitung loss pada data pelatihan

        # Evaluasi pada data pengujian
        test_output = model(X_test_tensor)
        test_pred = torch.argmax(test_output, dim=1)
        test_accuracy = accuracy_score(y_test_tensor.numpy(), test_pred.numpy())  # Menghitung akurasi data pengujian
        test_loss = criterion(test_output, y_test_tensor).item()  # Menghitung loss pada data pengujian

    # Mengembalikan hasil evaluasi: akurasi dan loss untuk data pelatihan dan pengujian
    return train_accuracy, train_loss, test_accuracy, test_loss

# %%
# Daftar hyperparameter untuk eksperimen
hidden_layers_options = [1, 2, 3]  # Jumlah lapisan tersembunyi
hidden_neurons_options = [8, 16, 32]  # Jumlah neuron di setiap lapisan tersembunyi
activation_functions = ['linear', 'Sigmoid', 'ReLU', 'Softmax', 'Tanh']  # Fungsi aktivasi yang digunakan
epochs_options = [10, 25, 50, 100]  # Jumlah epoch pelatihan
learning_rates = [0.1, 0.01, 0.001, 0.0001]  # Tingkat pembelajaran
batch_sizes = [64, 128, 256, 512]  # Ukuran batch data

# Melakukan eksperimen dengan semua kombinasi hyperparameter
results = []  # Menyimpan hasil eksperimen
best_result = None
worst_result = None

# Loop untuk setiap kombinasi hyperparameter
for hidden_layers in hidden_layers_options:
    for hidden_neurons in hidden_neurons_options:
        for activation_function in activation_functions:
            for epochs in epochs_options:
                for learning_rate in learning_rates:
                    for batch_size in batch_sizes:
                        # Menampilkan konfigurasi hyperparameter yang sedang diuji
                        print(f"Melatih model dengan: {hidden_layers} lapisan tersembunyi, {hidden_neurons} neuron per lapisan, "
                              f"aktivasi {activation_function}, {epochs} epoch, learning rate {learning_rate}, "
                              f"batch size {batch_size}")

                        # Membuat model dengan kombinasi hyperparameter saat ini
                        model = create_mlp(X_train_tensor.shape[1], hidden_layers, hidden_neurons, activation_function)

                        # Melatih dan mengevaluasi model
                        train_acc, train_loss, test_acc, test_loss = train_and_evaluate(
                            model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate
                        )

                        # Menyimpan hasil eksperimen saat ini
                        results.append({
                            'Hidden Layers': hidden_layers,
                            'Hidden Neurons': hidden_neurons,
                            'Activation Function': activation_function,
                            'Epochs': epochs,
                            'Learning Rate': learning_rate,
                            'Batch Size': batch_size,
                            'Train Accuracy': train_acc,
                            'Train Loss': train_loss,
                            'Test Accuracy': test_acc,
                            'Test Loss': test_loss
                        })

                        # Menampilkan hasil eksperimen
                        print(f"Akurasi Pelatihan: {train_acc * 100:.2f}%")
                        print(f"Loss Pelatihan: {train_loss:.4f}")
                        print(f"Akurasi Pengujian: {test_acc * 100:.2f}%")
                        print(f"Loss Pengujian: {test_loss:.4f}\n")

                        # Memperbarui hasil terbaik dan terburuk
                        if best_result is None or test_acc > best_result['Test Accuracy']:
                            best_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
                        if worst_result is None or test_acc < worst_result['Test Accuracy']:
                            worst_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss Pengujian: 0.6940
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Sigmoid, 100 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.6943
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6913
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 89.68%
# Loss Pelatihan: 0.2844
# Akurasi Pengujian: 85.71%
# Loss Pengujian: 0.3616
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 93.72%
# Loss Pelatihan: 0.1469
# Akurasi Pengujian: 88.31%
# Loss Pengujian: 0.3505
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 91.91%
# Loss Pelatihan: 0.2178
# Akurasi Pengujian: 87.01%
# Loss Pengujian: 0.3486
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3166
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4084
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 89.54%
# Loss Pelatihan: 0.2357
# Akurasi Pengujian: 86.69%
# Loss Pengujian: 0.3209
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 89.26%
# Loss Pelatihan: 0.2627
# Akurasi Pengujian: 83.12%
# Loss Pengujian: 0.3413
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 87.87%
# Loss Pelatihan: 0.3097
# Akurasi Pengujian: 82.79%
# Loss Pengujian: 0.3779
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 85.36%
# Loss Pelatihan: 0.3534
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4397
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 84.52%
# Loss Pelatihan: 0.3883
# Akurasi Pengujian: 78.57%
# Loss Pengujian: 0.4335
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 77.27%
# Loss Pelatihan: 0.5846
# Akurasi Pengujian: 75.65%
# Loss Pengujian: 0.5891
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6591
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6715
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 73.08%
# Loss Pelatihan: 0.6792
# Akurasi Pengujian: 72.40%
# Loss Pengujian: 0.6786
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.6985
# Akurasi Pengujian: 52.60%
# Loss Pengujian: 0.6867
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 48.95%
# Loss Pelatihan: 0.6973
# Akurasi Pengujian: 52.27%
# Loss Pengujian: 0.6904
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 59.41%
# Loss Pelatihan: 0.6741
# Akurasi Pengujian: 61.69%
# Loss Pengujian: 0.6789
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 10 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7498
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.7294
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 96.93%
# Loss Pelatihan: 0.1021
# Akurasi Pengujian: 90.91%
# Loss Pengujian: 0.2730
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 95.68%
# Loss Pelatihan: 0.1086
# Akurasi Pengujian: 90.26%
# Loss Pengujian: 0.2379
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 94.70%
# Loss Pelatihan: 0.1608
# Akurasi Pengujian: 91.56%
# Loss Pengujian: 0.2608
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 96.09%
# Loss Pelatihan: 0.1017
# Akurasi Pengujian: 90.91%
# Loss Pengujian: 0.2902
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 94.70%
# Loss Pelatihan: 0.1273
# Akurasi Pengujian: 87.66%
# Loss Pengujian: 0.3435
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 95.40%
# Loss Pelatihan: 0.1231
# Akurasi Pengujian: 90.26%
# Loss Pengujian: 0.2232
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 91.91%
# Loss Pelatihan: 0.2453
# Akurasi Pengujian: 87.01%
# Loss Pengujian: 0.3263
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 89.12%
# Loss Pelatihan: 0.2876
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4156
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 87.59%
# Loss Pelatihan: 0.2987
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.3638
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 85.91%
# Loss Pelatihan: 0.3312
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.3954
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 83.12%
# Loss Pelatihan: 0.4952
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.5092
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 75.17%
# Loss Pelatihan: 0.6521
# Akurasi Pengujian: 73.38%
# Loss Pengujian: 0.6528
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 69.46%
# Loss Pelatihan: 0.6602
# Akurasi Pengujian: 67.21%
# Loss Pengujian: 0.6611
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 53.28%
# Loss Pelatihan: 0.6620
# Akurasi Pengujian: 49.35%
# Loss Pengujian: 0.6765
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7658
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.7352
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 25 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 51.32%
# Loss Pelatihan: 0.6896
# Akurasi Pengujian: 50.32%
# Loss Pengujian: 0.6907
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.2476
# Akurasi Pengujian: 83.44%
# Loss Pengujian: 0.3359
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 98.33%
# Loss Pelatihan: 0.0577
# Akurasi Pengujian: 94.48%
# Loss Pengujian: 0.3234
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 98.47%
# Loss Pelatihan: 0.0546
# Akurasi Pengujian: 93.83%
# Loss Pengujian: 0.5946
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 96.23%
# Loss Pelatihan: 0.1087
# Akurasi Pengujian: 92.21%
# Loss Pengujian: 0.1789
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 97.91%
# Loss Pelatihan: 0.0532
# Akurasi Pengujian: 94.81%
# Loss Pengujian: 0.1664
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 99.58%
# Loss Pelatihan: 0.0135
# Akurasi Pengujian: 97.73%
# Loss Pengujian: 0.2428
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 95.40%
# Loss Pelatihan: 0.1342
# Akurasi Pengujian: 91.23%
# Loss Pengujian: 0.2017
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 93.44%
# Loss Pelatihan: 0.1716
# Akurasi Pengujian: 88.96%
# Loss Pengujian: 0.2571
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 88.42%
# Loss Pelatihan: 0.2777
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.3859
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 90.24%
# Loss Pelatihan: 0.2879
# Akurasi Pengujian: 84.09%
# Loss Pengujian: 0.3842
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 0.3307
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4082
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 81.45%
# Loss Pelatihan: 0.4276
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.4565
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 76.85%
# Loss Pelatihan: 0.5831
# Akurasi Pengujian: 72.40%
# Loss Pengujian: 0.5942
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6461
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6596
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6926
# Akurasi Pengujian: 47.73%
# Loss Pengujian: 0.6999
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 50 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 55.09%
# Loss Pelatihan: 0.6673
# Akurasi Pengujian: 50.97%
# Loss Pengujian: 0.6751
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.2662
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.3626
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 95.26%
# Loss Pelatihan: 0.1036
# Akurasi Pengujian: 90.26%
# Loss Pengujian: 0.3907
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 97.35%
# Loss Pelatihan: 0.0437
# Akurasi Pengujian: 93.18%
# Loss Pengujian: 1.0814
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 96.37%
# Loss Pelatihan: 0.0725
# Akurasi Pengujian: 92.21%
# Loss Pengujian: 0.1983
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 99.30%
# Loss Pelatihan: 0.0256
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.0927
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0113
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.0865
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 99.44%
# Loss Pelatihan: 0.0147
# Akurasi Pengujian: 95.78%
# Loss Pengujian: 0.3393
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 97.21%
# Loss Pelatihan: 0.1198
# Akurasi Pengujian: 90.58%
# Loss Pengujian: 0.3450
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 92.75%
# Loss Pelatihan: 0.1731
# Akurasi Pengujian: 85.39%
# Loss Pengujian: 0.3832
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 94.14%
# Loss Pelatihan: 0.1788
# Akurasi Pengujian: 89.61%
# Loss Pengujian: 0.2823
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 89.40%
# Loss Pelatihan: 0.2805
# Akurasi Pengujian: 81.49%
# Loss Pengujian: 0.3775
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 87.45%
# Loss Pelatihan: 0.3130
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.3823
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 84.10%
# Loss Pelatihan: 0.3908
# Akurasi Pengujian: 82.47%
# Loss Pengujian: 0.4149
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 84.38%
# Loss Pelatihan: 0.4929
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.5147
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 65.83%
# Loss Pelatihan: 0.6457
# Akurasi Pengujian: 60.06%
# Loss Pengujian: 0.6534
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi ReLU, 100 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.6919
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6841
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 91.49%
# Loss Pelatihan: 0.2347
# Akurasi Pengujian: 86.04%
# Loss Pengujian: 0.3227
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 89.96%
# Loss Pelatihan: 0.2745
# Akurasi Pengujian: 85.71%
# Loss Pengujian: 0.3899
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 89.96%
# Loss Pelatihan: 0.3131
# Akurasi Pengujian: 85.39%
# Loss Pengujian: 0.3823
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 88.28%
# Loss Pelatihan: 0.3473
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.5145
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 88.28%
# Loss Pelatihan: 0.3188
# Akurasi Pengujian: 83.44%
# Loss Pengujian: 0.3778
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 85.50%
# Loss Pelatihan: 0.5277
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.5540
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6675
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6773
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 71.41%
# Loss Pelatihan: 0.6752
# Akurasi Pengujian: 66.88%
# Loss Pengujian: 0.6780
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6807
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6858
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6908
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6942
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6897
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6942
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6918
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6962
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.6965
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6927
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6916
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6963
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6921
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6953
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 10 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.7664
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.7381
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 95.26%
# Loss Pelatihan: 0.1482
# Akurasi Pengujian: 91.88%
# Loss Pengujian: 0.2307
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 91.91%
# Loss Pelatihan: 0.2103
# Akurasi Pengujian: 88.64%
# Loss Pengujian: 0.3185
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 95.12%
# Loss Pelatihan: 0.1721
# Akurasi Pengujian: 90.91%
# Loss Pengujian: 0.2554
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 93.03%
# Loss Pelatihan: 0.2170
# Akurasi Pengujian: 89.61%
# Loss Pengujian: 0.2936
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 91.77%
# Loss Pelatihan: 0.2263
# Akurasi Pengujian: 87.34%
# Loss Pengujian: 0.2856
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 90.79%
# Loss Pelatihan: 0.2613
# Akurasi Pengujian: 86.04%
# Loss Pengujian: 0.3719
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 89.12%
# Loss Pelatihan: 0.3004
# Akurasi Pengujian: 84.09%
# Loss Pengujian: 0.3800
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 84.10%
# Loss Pelatihan: 0.5060
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.5301
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 78.94%
# Loss Pelatihan: 0.6327
# Akurasi Pengujian: 74.35%
# Loss Pengujian: 0.6427
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 53.14%
# Loss Pelatihan: 0.6805
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6854
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6889
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6936
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6915
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6965
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6912
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6969
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.6983
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6925
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.6961
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6924
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 25 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6935
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.7040
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 95.26%
# Loss Pelatihan: 0.1699
# Akurasi Pengujian: 89.61%
# Loss Pengujian: 0.3159
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 94.00%
# Loss Pelatihan: 0.2022
# Akurasi Pengujian: 90.91%
# Loss Pengujian: 0.3303
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 95.12%
# Loss Pelatihan: 0.1931
# Akurasi Pengujian: 92.53%
# Loss Pengujian: 0.2876
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 96.51%
# Loss Pelatihan: 0.1521
# Akurasi Pengujian: 94.48%
# Loss Pengujian: 0.1942
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 95.68%
# Loss Pelatihan: 0.1277
# Akurasi Pengujian: 91.23%
# Loss Pengujian: 0.2315
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 95.12%
# Loss Pelatihan: 0.1704
# Akurasi Pengujian: 92.21%
# Loss Pengujian: 0.2296
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 92.61%
# Loss Pelatihan: 0.2135
# Akurasi Pengujian: 88.31%
# Loss Pengujian: 0.3091
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 90.24%
# Loss Pelatihan: 0.2884
# Akurasi Pengujian: 84.74%
# Loss Pengujian: 0.4116
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3208
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.4005
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 82.57%
# Loss Pelatihan: 0.5005
# Akurasi Pengujian: 77.92%
# Loss Pengujian: 0.5175
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6844
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6898
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6894
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6939
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6897
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6934
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6910
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6967
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6916
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6962
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 50 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6911
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6935
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 95.54%
# Loss Pelatihan: 0.1805
# Akurasi Pengujian: 92.53%
# Loss Pengujian: 0.2857
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 96.37%
# Loss Pelatihan: 0.1622
# Akurasi Pengujian: 92.86%
# Loss Pengujian: 0.2985
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 96.93%
# Loss Pelatihan: 0.1283
# Akurasi Pengujian: 95.45%
# Loss Pengujian: 0.2081
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 96.51%
# Loss Pelatihan: 0.1333
# Akurasi Pengujian: 92.21%
# Loss Pengujian: 0.2704
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 96.65%
# Loss Pelatihan: 0.0786
# Akurasi Pengujian: 94.16%
# Loss Pengujian: 0.1447
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 97.07%
# Loss Pelatihan: 0.1441
# Akurasi Pengujian: 94.48%
# Loss Pengujian: 0.2094
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 97.63%
# Loss Pelatihan: 0.0953
# Akurasi Pengujian: 95.78%
# Loss Pengujian: 0.1640
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 95.82%
# Loss Pelatihan: 0.1728
# Akurasi Pengujian: 90.58%
# Loss Pengujian: 0.2625
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 89.96%
# Loss Pelatihan: 0.2840
# Akurasi Pengujian: 84.09%
# Loss Pengujian: 0.3770
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 87.87%
# Loss Pelatihan: 0.3190
# Akurasi Pengujian: 83.44%
# Loss Pengujian: 0.3861
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 83.82%
# Loss Pelatihan: 0.4170
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4496
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 53.42%
# Loss Pelatihan: 0.6814
# Akurasi Pengujian: 49.03%
# Loss Pengujian: 0.6848
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6885
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6931
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6912
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6955
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 47.42%
# Loss Pelatihan: 0.6930
# Akurasi Pengujian: 51.62%
# Loss Pengujian: 0.6925
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6999
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.7150
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 94.28%
# Loss Pelatihan: 0.1915
# Akurasi Pengujian: 91.88%
# Loss Pengujian: 0.2392
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 91.77%
# Loss Pelatihan: 0.1765
# Akurasi Pengujian: 85.71%
# Loss Pengujian: 0.3253
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 90.24%
# Loss Pelatihan: 0.2372
# Akurasi Pengujian: 82.79%
# Loss Pengujian: 0.3817
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 91.35%
# Loss Pelatihan: 0.2563
# Akurasi Pengujian: 84.09%
# Loss Pengujian: 0.3340
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 91.49%
# Loss Pelatihan: 0.2665
# Akurasi Pengujian: 86.36%
# Loss Pengujian: 0.3549
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 88.70%
# Loss Pelatihan: 0.2895
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.3914
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 87.45%
# Loss Pelatihan: 0.3200
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.3894
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 87.03%
# Loss Pelatihan: 0.3453
# Akurasi Pengujian: 82.47%
# Loss Pengujian: 0.4331
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 84.66%
# Loss Pelatihan: 0.3731
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4156
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 82.29%
# Loss Pelatihan: 0.5424
# Akurasi Pengujian: 77.92%
# Loss Pengujian: 0.5584
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 78.10%
# Loss Pelatihan: 0.6605
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.6600
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 62.06%
# Loss Pelatihan: 0.6443
# Akurasi Pengujian: 60.71%
# Loss Pengujian: 0.6556
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 45.75%
# Loss Pelatihan: 0.7009
# Akurasi Pengujian: 43.51%
# Loss Pengujian: 0.7038
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 44.07%
# Loss Pelatihan: 0.7128
# Akurasi Pengujian: 50.00%
# Loss Pengujian: 0.7051
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 47.84%
# Loss Pelatihan: 0.6905
# Akurasi Pengujian: 51.30%
# Loss Pengujian: 0.6855
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 67.64%
# Loss Pelatihan: 0.6680
# Akurasi Pengujian: 67.53%
# Loss Pengujian: 0.6684
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 95.40%
# Loss Pelatihan: 0.1519
# Akurasi Pengujian: 92.21%
# Loss Pengujian: 0.2391
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 97.63%
# Loss Pelatihan: 0.0938
# Akurasi Pengujian: 94.48%
# Loss Pengujian: 0.1620
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 96.51%
# Loss Pelatihan: 0.1063
# Akurasi Pengujian: 90.91%
# Loss Pengujian: 0.3182
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 96.93%
# Loss Pelatihan: 0.1463
# Akurasi Pengujian: 96.43%
# Loss Pengujian: 0.1819
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 96.09%
# Loss Pelatihan: 0.1334
# Akurasi Pengujian: 90.58%
# Loss Pengujian: 0.2799
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 95.54%
# Loss Pelatihan: 0.1540
# Akurasi Pengujian: 89.61%
# Loss Pengujian: 0.2328
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 90.24%
# Loss Pelatihan: 0.2756
# Akurasi Pengujian: 83.12%
# Loss Pengujian: 0.3650
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 88.84%
# Loss Pelatihan: 0.2946
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4003
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 87.59%
# Loss Pelatihan: 0.3142
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.3970
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 86.75%
# Loss Pelatihan: 0.3395
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4036
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 83.68%
# Loss Pelatihan: 0.4142
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.4283
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 79.64%
# Loss Pelatihan: 0.4922
# Akurasi Pengujian: 77.60%
# Loss Pengujian: 0.5149
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 63.32%
# Loss Pelatihan: 0.6804
# Akurasi Pengujian: 63.31%
# Loss Pengujian: 0.6814
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.7139
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.7294
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 66.39%
# Loss Pelatihan: 0.6393
# Akurasi Pengujian: 62.99%
# Loss Pengujian: 0.6506
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6766
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6892
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 95.96%
# Loss Pelatihan: 0.1449
# Akurasi Pengujian: 92.21%
# Loss Pengujian: 0.2208
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 99.02%
# Loss Pelatihan: 0.0376
# Akurasi Pengujian: 92.86%
# Loss Pengujian: 0.4102
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 98.74%
# Loss Pelatihan: 0.0416
# Akurasi Pengujian: 97.73%
# Loss Pengujian: 0.0766
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 99.58%
# Loss Pelatihan: 0.0203
# Akurasi Pengujian: 95.78%
# Loss Pengujian: 0.2167
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0013
# Akurasi Pengujian: 99.03%
# Loss Pengujian: 0.0840
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 99.16%
# Loss Pelatihan: 0.0315
# Akurasi Pengujian: 96.75%
# Loss Pengujian: 0.1089
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 98.47%
# Loss Pelatihan: 0.0472
# Akurasi Pengujian: 95.13%
# Loss Pengujian: 0.1960
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 94.56%
# Loss Pelatihan: 0.1772
# Akurasi Pengujian: 90.26%
# Loss Pengujian: 0.2732
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 88.56%
# Loss Pelatihan: 0.2936
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.3862
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 88.28%
# Loss Pelatihan: 0.3100
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4000
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3402
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.3913
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 84.66%
# Loss Pelatihan: 0.3814
# Akurasi Pengujian: 82.47%
# Loss Pengujian: 0.4177
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 75.31%
# Loss Pelatihan: 0.5571
# Akurasi Pengujian: 72.08%
# Loss Pengujian: 0.5737
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 63.46%
# Loss Pelatihan: 0.6548
# Akurasi Pengujian: 60.06%
# Loss Pengujian: 0.6660
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 71.27%
# Loss Pelatihan: 0.6272
# Akurasi Pengujian: 71.10%
# Loss Pengujian: 0.6306
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 60.53%
# Loss Pelatihan: 0.6834
# Akurasi Pengujian: 54.55%
# Loss Pengujian: 0.6887
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 97.91%
# Loss Pelatihan: 0.0485
# Akurasi Pengujian: 93.18%
# Loss Pengujian: 0.1885
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 77.96%
# Loss Pelatihan: 0.6855
# Akurasi Pengujian: 73.05%
# Loss Pengujian: 0.8531
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 99.16%
# Loss Pelatihan: 0.0195
# Akurasi Pengujian: 97.40%
# Loss Pengujian: 0.1449
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 97.91%
# Loss Pelatihan: 0.0556
# Akurasi Pengujian: 96.10%
# Loss Pengujian: 0.1987
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0002
# Akurasi Pengujian: 99.03%
# Loss Pengujian: 0.0901
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0004
# Akurasi Pengujian: 99.03%
# Loss Pengujian: 0.1362
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0007
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.2915
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0023
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.1523
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 95.54%
# Loss Pelatihan: 0.1632
# Akurasi Pengujian: 90.91%
# Loss Pengujian: 0.2917
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 89.68%
# Loss Pelatihan: 0.2724
# Akurasi Pengujian: 84.09%
# Loss Pengujian: 0.3611
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3081
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.3948
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 87.73%
# Loss Pelatihan: 0.3255
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.3985
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 86.05%
# Loss Pelatihan: 0.3638
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.4079
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 79.64%
# Loss Pelatihan: 0.5090
# Akurasi Pengujian: 77.60%
# Loss Pengujian: 0.5224
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 62.06%
# Loss Pelatihan: 0.6425
# Akurasi Pengujian: 55.52%
# Loss Pengujian: 0.6635
#
# Melatih model dengan: 3 lapisan tersembunyi, 8 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 56.35%
# Loss Pelatihan: 0.6559
# Akurasi Pengujian: 51.30%
# Loss Pengujian: 0.6718
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 85.63%
# Loss Pelatihan: 0.3770
# Akurasi Pengujian: 78.25%
# Loss Pengujian: 0.4294
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 84.80%
# Loss Pelatihan: 0.4021
# Akurasi Pengujian: 83.44%
# Loss Pengujian: 0.4220
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 83.40%
# Loss Pelatihan: 1.7925
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 2.6588
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 52.72%
# Loss Pelatihan: 0.8343
# Akurasi Pengujian: 52.60%
# Loss Pengujian: 0.7812
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3359
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4105
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3348
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4208
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3363
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.4199
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 85.77%
# Loss Pelatihan: 0.3428
# Akurasi Pengujian: 79.55%
# Loss Pengujian: 0.3981
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 85.50%
# Loss Pelatihan: 0.3469
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.3906
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 83.40%
# Loss Pelatihan: 0.3775
# Akurasi Pengujian: 77.92%
# Loss Pengujian: 0.4313
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 77.55%
# Loss Pelatihan: 0.5268
# Akurasi Pengujian: 76.30%
# Loss Pengujian: 0.5348
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 81.73%
# Loss Pelatihan: 0.5915
# Akurasi Pengujian: 76.62%
# Loss Pengujian: 0.5932
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 62.34%
# Loss Pelatihan: 0.6572
# Akurasi Pengujian: 57.14%
# Loss Pengujian: 0.6652
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 64.44%
# Loss Pelatihan: 0.6716
# Akurasi Pengujian: 66.88%
# Loss Pengujian: 0.6763
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6940
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.7107
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 10 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 53.28%
# Loss Pelatihan: 0.6956
# Akurasi Pengujian: 46.75%
# Loss Pengujian: 0.7052
#
# Melatih model dengan: 3 lapisan tersembunyi, 16 neuron per lapisan, aktivasi linear, 25 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3430
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.4466
#
# ...
# Loss Pengujian: 0.3567
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 86.05%
# Loss Pelatihan: 0.4260
# Akurasi Pengujian: 82.47%
# Loss Pengujian: 0.4532
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6814
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6866
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6914
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6961
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6916
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6964
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6917
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6960
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Softmax, 100 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 52.58%
# Loss Pelatihan: 0.6917
# Akurasi Pengujian: 48.38%
# Loss Pengujian: 0.6960
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 97.49%
# Loss Pelatihan: 0.0692
# Akurasi Pengujian: 96.10%
# Loss Pengujian: 0.0986
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 98.74%
# Loss Pelatihan: 0.0538
# Akurasi Pengujian: 95.13%
# Loss Pengujian: 0.1162
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 91.63%
# Loss Pelatihan: 1.6389
# Akurasi Pengujian: 88.96%
# Loss Pengujian: 2.3619
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 86.47%
# Loss Pelatihan: 3.1105
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 5.1535
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 94.42%
# Loss Pelatihan: 0.1680
# Akurasi Pengujian: 87.01%
# Loss Pengujian: 0.2792
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 94.14%
# Loss Pelatihan: 0.1889
# Akurasi Pengujian: 87.99%
# Loss Pengujian: 0.2855
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3036
# Akurasi Pengujian: 79.87%
# Loss Pengujian: 0.4045
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3267
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.4192
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 87.31%
# Loss Pelatihan: 0.3269
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.3932
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3378
# Akurasi Pengujian: 82.79%
# Loss Pengujian: 0.3985
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 81.03%
# Loss Pelatihan: 0.4558
# Akurasi Pengujian: 76.95%
# Loss Pengujian: 0.4765
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 82.85%
# Loss Pelatihan: 0.4666
# Akurasi Pengujian: 77.92%
# Loss Pengujian: 0.4904
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 82.15%
# Loss Pelatihan: 0.5871
# Akurasi Pengujian: 77.92%
# Loss Pengujian: 0.6036
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 66.53%
# Loss Pelatihan: 0.6274
# Akurasi Pengujian: 64.29%
# Loss Pengujian: 0.6375
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 66.95%
# Loss Pelatihan: 0.6750
# Akurasi Pengujian: 63.96%
# Loss Pengujian: 0.6758
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 10 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 65.83%
# Loss Pelatihan: 0.6488
# Akurasi Pengujian: 65.26%
# Loss Pengujian: 0.6483
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0002
# Akurasi Pengujian: 99.03%
# Loss Pengujian: 0.0383
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0003
# Akurasi Pengujian: 97.08%
# Loss Pengujian: 0.1198
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 99.02%
# Loss Pelatihan: 0.0395
# Akurasi Pengujian: 96.75%
# Loss Pengujian: 0.1077
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 96.65%
# Loss Pelatihan: 0.0930
# Akurasi Pengujian: 92.53%
# Loss Pengujian: 0.1683
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0009
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.0909
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 99.86%
# Loss Pelatihan: 0.0175
# Akurasi Pengujian: 97.40%
# Loss Pengujian: 0.1064
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 96.65%
# Loss Pelatihan: 0.0655
# Akurasi Pengujian: 93.83%
# Loss Pengujian: 0.1643
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 95.26%
# Loss Pelatihan: 0.1409
# Akurasi Pengujian: 89.61%
# Loss Pengujian: 0.2375
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 89.82%
# Loss Pelatihan: 0.2843
# Akurasi Pengujian: 84.09%
# Loss Pengujian: 0.3856
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3091
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.3946
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 86.05%
# Loss Pelatihan: 0.3296
# Akurasi Pengujian: 80.52%
# Loss Pengujian: 0.3991
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 85.08%
# Loss Pelatihan: 0.3409
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.3830
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 83.96%
# Loss Pelatihan: 0.4020
# Akurasi Pengujian: 80.19%
# Loss Pengujian: 0.4261
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 80.75%
# Loss Pelatihan: 0.5275
# Akurasi Pengujian: 78.90%
# Loss Pengujian: 0.5319
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 56.90%
# Loss Pelatihan: 0.6557
# Akurasi Pengujian: 61.36%
# Loss Pengujian: 0.6486
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 25 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 51.74%
# Loss Pelatihan: 0.6777
# Akurasi Pengujian: 55.19%
# Loss Pengujian: 0.6692
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0000
# Akurasi Pengujian: 97.08%
# Loss Pengujian: 0.5883
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0001
# Akurasi Pengujian: 99.03%
# Loss Pengujian: 0.2447
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0006
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.1718
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0010
# Akurasi Pengujian: 96.10%
# Loss Pengujian: 0.1848
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0001
# Akurasi Pengujian: 97.08%
# Loss Pengujian: 0.2803
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0001
# Akurasi Pengujian: 97.08%
# Loss Pengujian: 0.4358
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0002
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.1382
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0035
# Akurasi Pengujian: 97.08%
# Loss Pengujian: 0.2386
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 97.91%
# Loss Pelatihan: 0.0551
# Akurasi Pengujian: 93.51%
# Loss Pengujian: 0.1775
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 91.35%
# Loss Pelatihan: 0.2350
# Akurasi Pengujian: 86.69%
# Loss Pengujian: 0.3095
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 88.84%
# Loss Pelatihan: 0.2892
# Akurasi Pengujian: 81.17%
# Loss Pengujian: 0.3757
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 88.56%
# Loss Pelatihan: 0.2979
# Akurasi Pengujian: 83.12%
# Loss Pengujian: 0.3624
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 86.33%
# Loss Pelatihan: 0.3447
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.3990
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 85.36%
# Loss Pelatihan: 0.3717
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4088
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 80.89%
# Loss Pelatihan: 0.5556
# Akurasi Pengujian: 78.25%
# Loss Pengujian: 0.5636
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 50 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 73.92%
# Loss Pelatihan: 0.6106
# Akurasi Pengujian: 75.65%
# Loss Pengujian: 0.6094
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.1, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0000
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.3219
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.1, batch size 128
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0000
# Akurasi Pengujian: 99.03%
# Loss Pengujian: 0.0795
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.1, batch size 256
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0000
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.1521
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.1, batch size 512
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0000
# Akurasi Pengujian: 99.03%
# Loss Pengujian: 0.0837
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.01, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0000
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.1868
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.01, batch size 128
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0000
# Akurasi Pengujian: 97.08%
# Loss Pengujian: 0.2006
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.01, batch size 256
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0001
# Akurasi Pengujian: 97.08%
# Loss Pengujian: 0.5985
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.01, batch size 512
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0001
# Akurasi Pengujian: 97.08%
# Loss Pengujian: 0.2377
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.001, batch size 64
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0022
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.1599
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.001, batch size 128
# Akurasi Pelatihan: 100.00%
# Loss Pelatihan: 0.0057
# Akurasi Pengujian: 98.05%
# Loss Pengujian: 0.0891
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.001, batch size 256
# Akurasi Pelatihan: 96.93%
# Loss Pelatihan: 0.1063
# Akurasi Pengujian: 93.83%
# Loss Pengujian: 0.1681
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.001, batch size 512
# Akurasi Pelatihan: 91.21%
# Loss Pelatihan: 0.2295
# Akurasi Pengujian: 82.14%
# Loss Pengujian: 0.3249
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.0001, batch size 64
# Akurasi Pelatihan: 86.89%
# Loss Pelatihan: 0.3188
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.3927
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.0001, batch size 128
# Akurasi Pelatihan: 87.17%
# Loss Pelatihan: 0.3320
# Akurasi Pengujian: 81.82%
# Loss Pengujian: 0.3915
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.0001, batch size 256
# Akurasi Pelatihan: 83.68%
# Loss Pelatihan: 0.3731
# Akurasi Pengujian: 80.84%
# Loss Pengujian: 0.4172
#
# Melatih model dengan: 3 lapisan tersembunyi, 32 neuron per lapisan, aktivasi Tanh, 100 epoch, learning rate 0.0001, batch size 512
# Akurasi Pelatihan: 80.06%
# Loss Pelatihan: 0.4608
# Akurasi Pengujian: 77.27%
# Loss Pengujian: 0.4689

# %%
# Menampilkan best dan worst hyperparameter berdasarkan akurasi
print("\nBest Hyperparameter Configuration:")
print(f"Hidden Layers: {best_result['Hyperparameters']['Hidden Layers']}")
print(f"Hidden Neurons: {best_result['Hyperparameters']['Hidden Neurons']}")
print(f"Activation Function: {best_result['Hyperparameters']['Activation Function']}")
print(f"Epochs: {best_result['Hyperparameters']['Epochs']}")
print(f"Learning Rate: {best_result['Hyperparameters']['Learning Rate']}")
print(f"Batch Size: {best_result['Hyperparameters']['Batch Size']}")
print(f"Test Accuracy: {best_result['Test Accuracy'] * 100:.2f}%")
# Out:
# Best Hyperparameter Configuration:
# Hidden Layers: 2
# Hidden Neurons: 16
# Activation Function: Sigmoid
# Epochs: 100
# Learning Rate: 0.1
# Batch Size: 128
# Test Accuracy: 100.00%

# %%
# Menampilkan hyperparameter terburuk berdasarkan akurasi terendah
print("\nWorst Hyperparameter Configuration:")
print(f"Hidden Layers: {worst_result['Hyperparameters']['Hidden Layers']}")
print(f"Hidden Neurons: {worst_result['Hyperparameters']['Hidden Neurons']}")
print(f"Activation Function: {worst_result['Hyperparameters']['Activation Function']}")
print(f"Epochs: {worst_result['Hyperparameters']['Epochs']}")
print(f"Learning Rate: {worst_result['Hyperparameters']['Learning Rate']}")
print(f"Batch Size: {worst_result['Hyperparameters']['Batch Size']}")
print(f"Test Accuracy: {worst_result['Test Accuracy'] * 100:.2f}%")
# Out:
# Worst Hyperparameter Configuration:
# Hidden Layers: 1
# Hidden Neurons: 8
# Activation Function: linear
# Epochs: 25
# Learning Rate: 0.0001
# Batch Size: 512
# Test Accuracy: 22.08%
